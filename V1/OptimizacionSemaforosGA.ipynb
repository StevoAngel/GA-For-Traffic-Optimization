# %%
import random
from SUMOSimulation import SUMO

# Ubicación de los archivos de simulación de la red vial:
infoSUMO = {
    'projectFolder': r"SUMO_Simulation\RedVialZMG",
    'netFile': "\osm.net.xml", # Nombre del archivo que contiene la red
    'sumoCfgFile': "\osm.sumocfg" # Nombre del archivo principal de ejecución de SUMO
    }

#Dicionario de clusters de intersecciones: {id_custer: [tiempos en verde de cada semáforo], [archivos de detectores de vehículos]}
ampelDict = {"cluster_1395059763_1658290098": [[40, 50, 60], ["\Torres.xml", "\Belizario.xml", "\Torres2Belizario.xml"]]} 

# Parámetros de inicio del algoritmo genético:
SIMULATION_TIME = 900 # Tiempo de ejecución de la simulación en segundos
POPULATION_SIZE = 20
GENERATIONS = 50
CROSSOVER_ODDS = .8
MUTATION_ODDS = .2
MIN_TIME = 20 # Tiempo mínimo en verde
MAX_TIME = 120 # Tiempo máximo en verde

nAmpels = len(ampelDict["cluster_1395059763_1658290098"][0])


def generatePopulation():
    """Se genera la población inicial de manera aleatoria"""
    return [[random.randint(MIN_TIME, MAX_TIME) for _ in range(nAmpels)] for _ in range(POPULATION_SIZE)]

def calculateFitness(chromosome, vehicleRates):
    """Se calcula el tiempo total y penaliza los semáforos con flujo más bajo"""
    #totalTime = sum(chromosome) # Mayor tiempo en verde indica mayor flujo de autos
    totalFlow = 0 # Suma de tasas de flujos
    penalization = 0 # Penalización de tiempo para el cromosoma

    for i in range(len(chromosome)):
        time = chromosome[i] # Tiempo del alelo actual (semáforo)
        cVehicleRate = vehicleRates[i] # Tasa de vehiculos correspondiente al alelo actual (semáforo)
        flow = time * cVehicleRate # Factor de flujo = tiempo en verde * la casa de vehiculos del semáforo actual
        totalFlow += flow

        # Se penalizan largos tiempos en verde para tasas bajas de vehículos:
        if cVehicleRate < 0.1:
            penalization += (time - MIN_TIME) * 2

        #Calcular el fitness del cromosoma:
        fitness = totalFlow - penalization
    
    return fitness

def selection(population, fitness):
    """Se selecciona de manera elitista el mejor individuo de la generación"""
    fittedPopulation = list(zip(population, fitness)) # Se crean pares (población, fitness)
    bestFit = max(fittedPopulation, key=lambda x: x[1]) # Se selecciona el individuo con mejor fitness
    bestChromosome = bestFit[0] #Se guarda el mejor individuo

    return bestChromosome

def crossover(parent1, parent2):
    """Se ejecuta la cruza con el método de 'Cruza de un Punto' entre los padres"""
    if random.random() < CROSSOVER_ODDS:
        point = random.randint(1, nAmpels-1) #Se selecciona el punto de cruza
        child1 = parent1[:point] + parent2[point:] # De la cruza se genera el hijo 1
        child2 = parent2[:point] + parent1[point:] # De la cruza se genera el hijo 2

    else:
        child1 = parent1
        child2 = parent2

    return child1, child2

def mutation(chromosome):
    """Se ejecuta la mutación mediante 'Mutación Uniforme' de un gen"""
    if random.random() < MUTATION_ODDS:
        gen = random.randint(1, nAmpels-1)
        chromosome[gen] = random.randint(MIN_TIME, MAX_TIME)

    return chromosome

# %%
def ampelOptimizationGA(showSimulation=False):
    """Obtiene los mejores tiempos en un sistema de semáforos para optimizar los tiempos de espera en intersecciones"""
    population = generatePopulation()
    vehicleRates = [random.random() for _ in range(nAmpels)]
    
    for generation in range(GENERATIONS):
        next_generation = []
        #Obtener la aptitud de cada individuo:
        cFinesess = [calculateFitness(chromosome, vehicleRates) for chromosome in population]

        while len(next_generation) < POPULATION_SIZE:
            #Se aplica selección:
            parent1 = selection(population, cFinesess)
            parent2 = selection(population, cFinesess)

            #Se aplica la cruza:
            child1, child2 = crossover(parent1, parent2)

            #Se aplica la mutación:
            child1 = mutation(child1)
            child2 = mutation(child2)

            next_generation.append(child1) # Se pasa el primer hijo a la siguiente generación

            if len(next_generation) < POPULATION_SIZE: # Sí no se ha revasado el tamaño de población
                next_generation.append(child2) # Se agrega también el segundo hijo

        # Se reemplaza la población con la nueva generación:
        population = next_generation

        #Mejores parámetros de la generación:
        bestFitness = max(cFinesess)
        bestChromosome = population[cFinesess.index(bestFitness)]
        print(f"\nGeneración No. {generation}: Mejor aptitud = {bestFitness} | Mejor individuo = {bestChromosome}")

        #Simular con el mejor cromosoma de la generación:
        ampelDict['cluster_1395059763_1658290098'][0] = bestChromosome
        projectFolder = infoSUMO['projectFolder']
        netFile = infoSUMO['netFile']
        sumoCfgFile = infoSUMO['sumoCfgFile']

        print(f"Comenzando simulación con el mejor individuo: ")
        simulation = SUMO(ampelDict, projectFolder, netFile, sumoCfgFile, SIMULATION_TIME, showSimulation)
        vehicleRates = simulation.simulateConditions(900)['cluster_1395059763_1658290098']
        print(f"Tasa de vehículos: {vehicleRates}")

        # Se reemplaza la población con la nueva generación:

    return bestChromosome

def simulateBest(bestSolution):
    """Simular con las mejores condiciones del algoritmo en la GUI de SUMO"""
    projectFolder = infoSUMO['projectFolder']
    netFile = infoSUMO['netFile']
    sumoCfgFile = infoSUMO['sumoCfgFile']

    ampelDict['cluster_1395059763_1658290098'][0] = bestSolution
    print("\n*************** Iniciando simulación con la mejor solución del algoritmo genético ***************")
    simulation = SUMO(ampelDict, projectFolder, netFile, sumoCfgFile, SIMULATION_TIME, showSimulation=True)
    simulation.simulateConditions()

# %%
bestSolution = ampelOptimizationGA() # Pasar True como argumento para ver cada simulación (cada generación)
print(f"Mejor solución {bestSolution}")
simulateBest(bestSolution)
# Out:
# Generación No. 0: Mejor aptitud = 165.33890664366876 | Mejor individuo = [87, 109, 113]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 109 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 113 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.37777777777777777
# La tasa del semáforo 1 es de: 0.11555555555555555
# La tasa del semáforo 2 es de: 0.11222222222222222
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.37777777777777777, 0.11555555555555555, 0.11222222222222222]
#
# Generación No. 1: Mejor aptitud = 59.41444444444444 | Mejor individuo = [87, 120, 113]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 113 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.25
# La tasa del semáforo 1 es de: 0.15888888888888889
# La tasa del semáforo 2 es de: 0.06666666666666667
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.25, 0.15888888888888889, 0.06666666666666667]
#
# Generación No. 2: Mejor aptitud = -8.116666666666674 | Mejor individuo = [87, 120, 46]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 46 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.25
# La tasa del semáforo 1 es de: 0.1688888888888889
# La tasa del semáforo 2 es de: 0.042222222222222223
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.25, 0.1688888888888889, 0.042222222222222223]
#
# Generación No. 3: Mejor aptitud = -8.041111111111114 | Mejor individuo = [87, 120, 46]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 46 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3055555555555556
# La tasa del semáforo 1 es de: 0.17888888888888888
# La tasa del semáforo 2 es de: 0.04777777777777778
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3055555555555556, 0.17888888888888888, 0.04777777777777778]
#
# Generación No. 4: Mejor aptitud = -1.7522222222222226 | Mejor individuo = [87, 120, 46]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 46 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3055555555555556
# La tasa del semáforo 1 es de: 0.17888888888888888
# La tasa del semáforo 2 es de: 0.04777777777777778
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3055555555555556, 0.17888888888888888, 0.04777777777777778]
#
# Generación No. 5: Mejor aptitud = -1.7522222222222226 | Mejor individuo = [87, 120, 46]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 46 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3055555555555556
# La tasa del semáforo 1 es de: 0.17888888888888888
# La tasa del semáforo 2 es de: 0.04777777777777778
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3055555555555556, 0.17888888888888888, 0.04777777777777778]
#
# Generación No. 6: Mejor aptitud = 47.05333333333333 | Mejor individuo = [87, 120, 21]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 21 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3055555555555556
# La tasa del semáforo 1 es de: 0.17888888888888888
# La tasa del semáforo 2 es de: 0.04777777777777778
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3055555555555556, 0.17888888888888888, 0.04777777777777778]
#
# Generación No. 7: Mejor aptitud = 47.05333333333333 | Mejor individuo = [87, 120, 21]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 21 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3188888888888889
# La tasa del semáforo 1 es de: 0.18555555555555556
# La tasa del semáforo 2 es de: 0.03666666666666667
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3188888888888889, 0.18555555555555556, 0.03666666666666667]
#
# Generación No. 8: Mejor aptitud = 48.78 | Mejor individuo = [87, 56, 21]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 56 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 21 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3188888888888889
# La tasa del semáforo 1 es de: 0.18555555555555556
# La tasa del semáforo 2 es de: 0.03666666666666667
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3188888888888889, 0.18555555555555556, 0.03666666666666667]
#
# Generación No. 9: Mejor aptitud = 48.78 | Mejor individuo = [87, 120, 21]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 21 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.44333333333333336
# La tasa del semáforo 1 es de: 0.13333333333333333
# La tasa del semáforo 2 es de: 0.051111111111111114
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.44333333333333336, 0.13333333333333333, 0.051111111111111114]
#
# Generación No. 10: Mejor aptitud = 53.64333333333333 | Mejor individuo = [87, 120, 39]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 39 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3188888888888889
# La tasa del semáforo 1 es de: 0.18555555555555556
# La tasa del semáforo 2 es de: 0.03666666666666667
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3188888888888889, 0.18555555555555556, 0.03666666666666667]
#
# Generación No. 11: Mejor aptitud = 48.78 | Mejor individuo = [87, 120, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3522222222222222
# La tasa del semáforo 1 es de: 0.18888888888888888
# La tasa del semáforo 2 es de: 0.05
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3522222222222222, 0.18888888888888888, 0.05]
#
# Generación No. 12: Mejor aptitud = 54.309999999999995 | Mejor individuo = [87, 120, 88]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 88 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3111111111111111
# La tasa del semáforo 1 es de: 0.19
# La tasa del semáforo 2 es de: 0.03333333333333333
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3111111111111111, 0.19, 0.03333333333333333]
#
# Generación No. 13: Mejor aptitud = 50.53333333333333 | Mejor individuo = [87, 120, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.27
# La tasa del semáforo 1 es de: 0.18
# La tasa del semáforo 2 es de: 0.08222222222222222
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.27, 0.18, 0.08222222222222222]
#
# Generación No. 14: Mejor aptitud = 46.73444444444445 | Mejor individuo = [87, 120, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3111111111111111
# La tasa del semáforo 1 es de: 0.19
# La tasa del semáforo 2 es de: 0.03333333333333333
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3111111111111111, 0.19, 0.03333333333333333]
#
# Generación No. 15: Mejor aptitud = 50.53333333333333 | Mejor individuo = [87, 49, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 49 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3111111111111111
# La tasa del semáforo 1 es de: 0.19
# La tasa del semáforo 2 es de: 0.03333333333333333
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3111111111111111, 0.19, 0.03333333333333333]
#
# Generación No. 16: Mejor aptitud = 50.53333333333333 | Mejor individuo = [87, 110, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 110 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.47444444444444445
# La tasa del semáforo 1 es de: 0.11555555555555555
# La tasa del semáforo 2 es de: 0.04888888888888889
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.47444444444444445, 0.11555555555555555, 0.04888888888888889]
#
# Generación No. 17: Mejor aptitud = 56.121111111111105 | Mejor individuo = [87, 105, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 105 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.30333333333333334
# La tasa del semáforo 1 es de: 0.17777777777777778
# La tasa del semáforo 2 es de: 0.04
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.30333333333333334, 0.17777777777777778, 0.04]
#
# Generación No. 18: Mejor aptitud = 48.52333333333333 | Mejor individuo = [87, 120, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 120 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3477777777777778
# La tasa del semáforo 1 es de: 0.17333333333333334
# La tasa del semáforo 2 es de: 0.04
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3477777777777778, 0.17333333333333334, 0.04]
#
# Generación No. 19: Mejor aptitud = 51.85666666666667 | Mejor individuo = [87, 72, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 72 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3111111111111111
# La tasa del semáforo 1 es de: 0.19
# La tasa del semáforo 2 es de: 0.03333333333333333
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3111111111111111, 0.19, 0.03333333333333333]
#
# Generación No. 20: Mejor aptitud = 45.973333333333336 | Mejor individuo = [87, 96, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 96 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.39
# La tasa del semáforo 1 es de: 0.18222222222222223
# La tasa del semáforo 2 es de: 0.03777777777777778
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.39, 0.18222222222222223, 0.03777777777777778]
#
# Generación No. 21: Mejor aptitud = 52.178888888888885 | Mejor individuo = [87, 96, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 96 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.31444444444444447
# La tasa del semáforo 1 es de: 0.15
# La tasa del semáforo 2 es de: 0.03888888888888889
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.31444444444444447, 0.15, 0.03888888888888889]
#
# Generación No. 22: Mejor aptitud = 42.534444444444446 | Mejor individuo = [87, 96, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 96 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.31444444444444447
# La tasa del semáforo 1 es de: 0.15
# La tasa del semáforo 2 es de: 0.03888888888888889
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.31444444444444447, 0.15, 0.03888888888888889]
#
# Generación No. 23: Mejor aptitud = 42.534444444444446 | Mejor individuo = [87, 96, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 96 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.31444444444444447
# La tasa del semáforo 1 es de: 0.15
# La tasa del semáforo 2 es de: 0.03888888888888889
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.31444444444444447, 0.15, 0.03888888888888889]
#
# Generación No. 24: Mejor aptitud = 42.534444444444446 | Mejor individuo = [87, 96, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 96 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.31444444444444447
# La tasa del semáforo 1 es de: 0.15
# La tasa del semáforo 2 es de: 0.03888888888888889
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.31444444444444447, 0.15, 0.03888888888888889]
#
# Generación No. 25: Mejor aptitud = 42.534444444444446 | Mejor individuo = [87, 96, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 96 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.31444444444444447
# La tasa del semáforo 1 es de: 0.15
# La tasa del semáforo 2 es de: 0.03888888888888889
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.31444444444444447, 0.15, 0.03888888888888889]
#
# Generación No. 26: Mejor aptitud = 45.684444444444445 | Mejor individuo = [87, 117, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 117 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.31444444444444447
# La tasa del semáforo 1 es de: 0.15
# La tasa del semáforo 2 es de: 0.03888888888888889
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.31444444444444447, 0.15, 0.03888888888888889]
#
# Generación No. 27: Mejor aptitud = 45.684444444444445 | Mejor individuo = [87, 117, 60]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 117 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 60 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.33666666666666667
# La tasa del semáforo 1 es de: 0.19111111111111112
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.33666666666666667, 0.19111111111111112, 0.044444444444444446]
#
# Generación No. 28: Mejor aptitud = 52.538888888888884 | Mejor individuo = [87, 117, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 117 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.37
# La tasa del semáforo 1 es de: 0.16777777777777778
# La tasa del semáforo 2 es de: 0.07222222222222222
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.37, 0.16777777777777778, 0.07222222222222222]
#
# Generación No. 29: Mejor aptitud = 53.264444444444436 | Mejor individuo = [87, 117, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 117 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.33666666666666667
# La tasa del semáforo 1 es de: 0.19111111111111112
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.33666666666666667, 0.19111111111111112, 0.044444444444444446]
#
# Generación No. 30: Mejor aptitud = 52.538888888888884 | Mejor individuo = [87, 117, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 117 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.33666666666666667
# La tasa del semáforo 1 es de: 0.19111111111111112
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.33666666666666667, 0.19111111111111112, 0.044444444444444446]
#
# Generación No. 31: Mejor aptitud = 52.538888888888884 | Mejor individuo = [87, 117, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 117 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.33666666666666667
# La tasa del semáforo 1 es de: 0.19111111111111112
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.33666666666666667, 0.19111111111111112, 0.044444444444444446]
#
# Generación No. 32: Mejor aptitud = 52.538888888888884 | Mejor individuo = [87, 117, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 117 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.33666666666666667
# La tasa del semáforo 1 es de: 0.19111111111111112
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.33666666666666667, 0.19111111111111112, 0.044444444444444446]
#
# Generación No. 33: Mejor aptitud = 52.538888888888884 | Mejor individuo = [87, 33, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 33 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.33666666666666667
# La tasa del semáforo 1 es de: 0.19111111111111112
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.33666666666666667, 0.19111111111111112, 0.044444444444444446]
#
# Generación No. 34: Mejor aptitud = 40.69 | Mejor individuo = [87, 55, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 55 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.5288888888888889
# La tasa del semáforo 1 es de: 0.11
# La tasa del semáforo 2 es de: 0.06
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.5288888888888889, 0.11, 0.06]
#
# Generación No. 35: Mejor aptitud = 57.99333333333333 | Mejor individuo = [87, 98, 102]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 98 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 102 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.4111111111111111
# La tasa del semáforo 1 es de: 0.15222222222222223
# La tasa del semáforo 2 es de: 0.056666666666666664
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.4111111111111111, 0.15222222222222223, 0.056666666666666664]
#
# Generación No. 36: Mejor aptitud = 51.81777777777778 | Mejor individuo = [87, 98, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 98 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.2911111111111111
# La tasa del semáforo 1 es de: 0.14666666666666667
# La tasa del semáforo 2 es de: 0.06222222222222222
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.2911111111111111, 0.14666666666666667, 0.06222222222222222]
#
# Generación No. 37: Mejor aptitud = 40.94444444444444 | Mejor individuo = [87, 98, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 98 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.36666666666666664
# La tasa del semáforo 1 es de: 0.18888888888888888
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.36666666666666664, 0.18888888888888888, 0.044444444444444446]
#
# Generación No. 38: Mejor aptitud = 53.56666666666666 | Mejor individuo = [87, 110, 59]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 110 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 59 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.36666666666666664
# La tasa del semáforo 1 es de: 0.18888888888888888
# La tasa del semáforo 2 es de: 0.044444444444444446
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.36666666666666664, 0.18888888888888888, 0.044444444444444446]
#
# Generación No. 39: Mejor aptitud = 54.322222222222216 | Mejor individuo = [87, 114, 76]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 76 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.33
# La tasa del semáforo 1 es de: 0.16111111111111112
# La tasa del semáforo 2 es de: 0.057777777777777775
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.33, 0.16111111111111112, 0.057777777777777775]
#
# Generación No. 40: Mejor aptitud = 48.23222222222223 | Mejor individuo = [87, 114, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.31
# La tasa del semáforo 1 es de: 0.15777777777777777
# La tasa del semáforo 2 es de: 0.06666666666666667
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.31, 0.15777777777777777, 0.06666666666666667]
#
# Generación No. 41: Mejor aptitud = 46.29 | Mejor individuo = [87, 114, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3288888888888889
# La tasa del semáforo 1 es de: 0.1922222222222222
# La tasa del semáforo 2 es de: 0.043333333333333335
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3288888888888889, 0.1922222222222222, 0.043333333333333335]
#
# Generación No. 42: Mejor aptitud = 51.39333333333333 | Mejor individuo = [87, 114, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3288888888888889
# La tasa del semáforo 1 es de: 0.1922222222222222
# La tasa del semáforo 2 es de: 0.043333333333333335
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3288888888888889, 0.1922222222222222, 0.043333333333333335]
#
# Generación No. 43: Mejor aptitud = 51.39333333333333 | Mejor individuo = [87, 114, 114]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3288888888888889
# La tasa del semáforo 1 es de: 0.1922222222222222
# La tasa del semáforo 2 es de: 0.043333333333333335
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3288888888888889, 0.1922222222222222, 0.043333333333333335]
#
# Generación No. 44: Mejor aptitud = 51.39333333333333 | Mejor individuo = [87, 114, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.27444444444444444
# La tasa del semáforo 1 es de: 0.16444444444444445
# La tasa del semáforo 2 es de: 0.06666666666666667
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.27444444444444444, 0.16444444444444445, 0.06666666666666667]
#
# Generación No. 45: Mejor aptitud = 43.95666666666667 | Mejor individuo = [87, 114, 98]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 98 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3288888888888889
# La tasa del semáforo 1 es de: 0.1922222222222222
# La tasa del semáforo 2 es de: 0.043333333333333335
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3288888888888889, 0.1922222222222222, 0.043333333333333335]
#
# Generación No. 46: Mejor aptitud = 51.39333333333333 | Mejor individuo = [87, 114, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.27666666666666667
# La tasa del semáforo 1 es de: 0.17
# La tasa del semáforo 2 es de: 0.07
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.27666666666666667, 0.17, 0.07]
#
# Generación No. 47: Mejor aptitud = 44.85 | Mejor individuo = [87, 114, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3288888888888889
# La tasa del semáforo 1 es de: 0.1922222222222222
# La tasa del semáforo 2 es de: 0.043333333333333335
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3288888888888889, 0.1922222222222222, 0.043333333333333335]
#
# Generación No. 48: Mejor aptitud = 51.39333333333333 | Mejor individuo = [87, 114, 45]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 45 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3288888888888889
# La tasa del semáforo 1 es de: 0.1922222222222222
# La tasa del semáforo 2 es de: 0.043333333333333335
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3288888888888889, 0.1922222222222222, 0.043333333333333335]
#
# Generación No. 49: Mejor aptitud = 51.39333333333333 | Mejor individuo = [87, 114, 20]
# Comenzando simulación con el mejor individuo:
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3466666666666667
# La tasa del semáforo 1 es de: 0.19555555555555557
# La tasa del semáforo 2 es de: 0.07555555555555556
#
#  ************** Tasa de vehículos obtenida ****************
# Tasa de vehículos: [0.3466666666666667, 0.19555555555555557, 0.07555555555555556]
# Mejor solución [87, 114, 20]
#
# *************** Iniciando simulación con la mejor solución del algoritmo genético ***************
# Fase rrrrGGGGrrrrrrGGGGrr del semáforo cluster_1395059763_1658290098 modificada a 87 segundos.
# Fase GGGGrrrrrrGGGGrrrrrr del semáforo cluster_1395059763_1658290098 modificada a 114 segundos.
# Fase rrrrrrrrGGrrrrrrrrGG del semáforo cluster_1395059763_1658290098 modificada a 20 segundos.
#
#  **************** Simulación Completada ******************
# La tasa del semáforo 0 es de: 0.3288888888888889
# La tasa del semáforo 1 es de: 0.1922222222222222
# La tasa del semáforo 2 es de: 0.043333333333333335
#
#  ************** Tasa de vehículos obtenida ****************
